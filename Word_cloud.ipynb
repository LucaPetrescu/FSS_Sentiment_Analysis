# %% [markdown]
# **Step1:Prepare a CSV file with comments or statements**

# %% [markdown]
# **Step 2:Upload CSV file**

# %% [markdown]
# # New Section

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# **step 3: Get filename**

# %%
filename = next(iter(uploaded))
filename
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 filename = next(iter(uploaded))
#       2 filename
#
# NameError: name 'uploaded' is not defined

# %% [markdown]
# **Step 4: Read the file**

# %%
import pandas as pd
def load_housing_data(filename=filename):
   return pd.read_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 def load_housing_data(filename=filename):
#       3    return pd.read_csv(filename)
#
# NameError: name 'filename' is not defined

# %%
DataF=load_housing_data(filename)
DataF
#DataF['Comments']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 DataF=load_housing_data(filename)
#       2 DataF
#
# NameError: name 'load_housing_data' is not defined

# %% [markdown]
# **Step 5: Create a variable that contains all the text**

# %%
newtext=''
for t in DataF['Comments']:
  newtext+=t

newtext
# Out:
# 'First copy started loosing pages from the first reading session and continued thereafter.\nThen I requested a replacement and same story happened again.\nMuch as I am focused on the content of the book the form in which it comes is also important.\nYou can\'t sell books that are loosing pages so easily.B/W edition...the feel of the pages of an authentic o rielly publication is duly missing.Love the book but not sure why it’s in black and white and the images are so blurry..It covers a lot of subjects but very superficially, and uses almost exclusively outdated techniques.\nStill ok if you know absolutely nothing about the subject but it\'s nowhere wear a practical book, especially if you\'re looking for business applications... the word "practical" in the title might make you think about the word "applied", as in code. That was what I was expecting. This is a great book to give a manager to read about NLP. They will understand things at a high level after reading it. However it just does not get the job done for someone like myself looking to apply this knowledgeThis book is an introduction on how to apply NLP in the industrial setting. It provides an almost comprehensive big picture for the current main breakthroughs in this field. It is well-organized and combines the real-life case studies as well as the code. I highly recommend this book for beginners with little knowledge in NLP and professionals/researchers who want to get extra guidance for their work - basically I believe everybody will gain something after reading regardless of the experience level. This book is worth my money and time. Because of COVID-19, I spent my July 4th 2020 reading this book (see how engaging this book is!). I appreciate all the hard work of the authors and the influence they bring to us.As a new starter in NLP, I found this book very helpful. The authors have made sure that all aspects of NLP are explained very well, and I especially like the Named Entity Recognition section and End to End NLP Process. Code accompanied with this book is beneficial. As a coder I could easily connect it with the text.I recommend this book for anyone interested in exploring the world of NLP.\n\nI will give this book five stars and must be on the shelves of NLP Developers. I wish the diagrams were coloured and not monochrome.I\'ve only finished the first chapter, but the quality of the writing is low. I\'m disappointed.Lots of information and fun to read.The authors intent this book to be for anyone who is interested in or working in the field.As others have mentioned, the Kindle version is horrrrrrible, not even worth the $9.99 price.Ordered as part of my Business Analytics course in my Masters.'

# %% [markdown]
# **Step 6: Configure the word cloud and remove Stopwords**

# %%
from wordcloud import WordCloud, STOPWORDS
import sys, os

# %%
wc=WordCloud(
    background_color='white',
    stopwords=STOPWORDS,
    height=600,
    width=400

)

# %%
wc.generate(newtext)

# %% [markdown]
# **Step 7:Display the word cloud and save it in a file**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,12))
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
wc.to_file('Wcloud2.png')
